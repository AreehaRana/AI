# %% [markdown]
# ## March 2,2026
# ## Monday

# %%
#Create a parent class Animal with method sound().Create child classes:DogCatCowEach child should override sound() method
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Dog says: Bark")

class Cat(Animal):
    def sound(self):
        print("Cat says: Meow")

class Cow(Animal):
    def sound(self):
        print("Cow says: Moo")
animals = [Dog(), Cat(), Cow()]

for animal in animals:
    animal.sound()
# Out:
# Dog says: Bark
# Cat says: Meow
# Cow says: Moo

# %%
#Vehical Momvement
class Vehical:
    def move(self):
        print("vehical move")
class Car(Vehical):
    def move(self):
        print("car can move")
class Bike(Vehical):
    print("bike can move")
class Bus(Vehical):
    print("bus can move")
Vehicals = [Car(),Bike(),Bus()]
for Vehical in Vehicals:
    Vehical.move()
# Out:
# bike can move
# bus can move
# car can move
# vehical move
# vehical move

# %%
#Area calculation
class Shape:
    def __init__(self,area):
        self.area =area
class Rectangle(Shape):
    def __init__(self,length,width):
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width
        
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def area(self):
          return 2 * 3.14 * self.radius
          
class Triangle(Shape):
    def __init__(self,base,height):
        self.base = base
        self.height = height
    def area(self):
        return 0.5*self.base *self.height
        
Shapes = [
    Rectangle(2,3),
    Circle(4),
    Triangle(4,7)
]
for shape in Shapes:
    print(f"Area:{shape.area()}")
# Out:
# Area:6
# Area:25.12
# Area:14.0

# %%
#base class employee
class Employee:
    def get_role(self):
        pass
        
class Manager(Employee):
    def get_role(self):
        return "Manage all oversease projects"
class Developer (Employee):
    def get_role(self):
        return "Devlope flutter apps"
class Designer (Employee):
    def get_role(self):
        return "design figma code"
Employees = [
    Manager(), Developer() , Designer()
]
for Employee in Employees:
    print(Employee.get_role())
# Out:
# Manage all oversease projects
# Devlope flutter apps
# design figma code

# %%
# Payment Processing System

class Payment:
    def pay(self, amount):
        self.amount = amount
        print("Processing payment of", self.amount)

class CreditCardPayment(Payment):
    def pay(self, amount):
        print("Processing Credit Card payment of", amount)

class JazzCashPayment(Payment):
    def pay(self, amount):
        print("Processing JazzCash payment of", amount)

class BankTransferPayment(Payment):
    def pay(self, amount):
        print("Processing Bank Transfer payment of", amount)

payments = [
    CreditCardPayment(),
    JazzCashPayment(),
    BankTransferPayment()
]

for i in payments:
    i.pay(100)
# Out:
# Processing Credit Card payment of 100
# Processing JazzCash payment of 100
# Processing Bank Transfer payment of 100
