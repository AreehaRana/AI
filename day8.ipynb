# %% [markdown]
# ## Feb 23 2026 Monday

# %%
def test():
    print("Hello")

test()
print(test())
# Out:
# Hello
# Hello
# None

# %%
def add(a, b):
    print(a + b)

result = add(2, 3)
print(result)
# Out:
# 5
# None

# %%
x = 10 # Global varibale
def test():
    x = 5
    print(x)
test()
print(x) # Local variable
# Out:
# 5
# 10

# %%
x = 10
def test():
    global x
    x = 20
test()
print(x)
# Out:
# 20

# %%
def add(a, b):
    print(a + b)

result = add(2, 3)
# Out:
# 5
