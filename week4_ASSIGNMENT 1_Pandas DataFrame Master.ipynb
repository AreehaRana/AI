# %% [markdown]
# ##ASSIGNMENT 1: Pandas DataFrame Master

# %%
import pandas as pd
import numpy as np
employees = pd.DataFrame({
    'emp_id': [1, 2, 3, 4],
    'name': ['Ali', 'Bilal', 'Ahmed', 'Sara'],
    'dept_id': [101, 102, 101, 103]
})
departments = pd.DataFrame({
    'dept_id': [101, 102, 104],
    'dept_name': ['HR', 'IT', 'Finance']
})
salaries = pd.DataFrame({
    'emp_id': [1, 2, 3, 4],
    'salary': [50000, 70000, 90000, 60000]
})
inner_join = pd.merge(employees, departments, on='dept_id', how='inner')
print("Inner Join:", inner_join)

left_join = pd.merge(employees, departments, on='dept_id', how='left')
print("Left Join:", left_join)

outer_join = pd.merge(employees, departments, on='dept_id', how='outer')
print("Outer Join:", outer_join)
new_employees = pd.DataFrame({
    'emp_id': [5, 6],
    'name': ['Zara', 'Usman'],
    'dept_id': [102, 104]
})

employees = pd.concat([employees, new_employees], ignore_index=True)
print("After Concatenation:", employees)
emp_salary = pd.merge(employees, salaries, on='emp_id', how='left')

emp_salary = pd.merge(emp_salary, departments, on='dept_id', how='left')

print("Employee + Salary + Department:", emp_salary)

avg_salary = emp_salary.groupby('dept_name')['salary'].mean()
print("Average Salary by Department:", avg_salary)

bins = [0, 60000, 80000, 100000]
labels = ['Low', 'Medium', 'High']

emp_salary['salary_category'] = pd.cut(emp_salary['salary'], bins=bins, labels=labels)

print("With Salary Category:", emp_salary)

emp_salary.to_csv('employee_summary.csv', index=False)

print("CSV file 'employee_summary.csv' saved successfully!")
# Out:
# Inner Join:
#     emp_id   name  dept_id dept_name
# 0       1    Ali      101        HR
# 1       2  Bilal      102        IT
# 2       3  Ahmed      101        HR
#
# Left Join:
#     emp_id   name  dept_id dept_name
# 0       1    Ali      101        HR
# 1       2  Bilal      102        IT
# 2       3  Ahmed      101        HR
# 3       4   Sara      103       NaN
#
# Outer Join:
#     emp_id   name  dept_id dept_name
# 0     1.0    Ali      101        HR
# 1     3.0  Ahmed      101        HR
# 2     2.0  Bilal      102        IT
# 3     4.0   Sara      103       NaN
# 4     NaN    NaN      104   Finance
#
# After Concatenation:
#     emp_id   name  dept_id
# 0       1    Ali      101
# 1       2  Bilal      102
# 2       3  Ahmed      101
# 3       4   Sara      103
# 4       5   Zara      102
# 5       6  Usman      104
#
# Employee + Salary + Department:
#     emp_id   name  dept_id   salary dept_name
# 0       1    Ali      101  50000.0        HR
# 1       2  Bilal      102  70000.0        IT
# 2       3  Ahmed      101  90000.0        HR
# 3       4   Sara      103  60000.0       NaN
# 4       5   Zara      102      NaN        IT
# 5       6  Usman      104      NaN   Finance
#
# Average Salary by Department:
#  dept_name
# Finance        NaN
# HR         70000.0
# IT         70000.0
# Name: salary, dtype: float64
#
# With Salary Category:
#     emp_id   name  dept_id   salary dept_name salary_category
# 0       1    Ali      101  50000.0        HR             Low
# 1       2  Bilal      102  70000.0        IT          Medium
# 2       3  Ahmed      101  90000.0        HR            High
# 3       4   Sara      103  60000.0       NaN             Low
# 4       5   Zara      102      NaN        IT             NaN
# 5       6  Usman      104      NaN   Finance             NaN
#
# CSV file 'employee_summary.csv' saved successfully!
