# %% [markdown]
# ## Heart Disease Prediction

# %%
#import libraries
import tensorflow as tf
import pandas as pd
import keras
from keras.utils import FeatureSpace
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split

# %%
# import dataset
df = pd.read_csv("framingham.csv")

# %%
df.shape
# Out:
# (4240, 16)

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
df.corr(numeric_only=True)
# Out:
#                      male       age  education  currentSmoker  cigsPerDay  \
# male             1.000000 -0.029014   0.017415       0.197026    0.317143
# age             -0.029014  1.000000  -0.166356      -0.213662   -0.192959
# education        0.017415 -0.166356   1.000000       0.018528    0.008323
# currentSmoker    0.197026 -0.213662   0.018528       1.000000    0.769774
# cigsPerDay       0.317143 -0.192959   0.008323       0.769774    1.000000
# BPMeds          -0.052504  0.123052  -0.010898      -0.048927   -0.046155
# prevalentStroke -0.004550  0.057679  -0.035142      -0.032980   -0.032711
# prevalentHyp     0.005853  0.306799  -0.081726      -0.103710   -0.066645
# diabetes         0.015693  0.101314  -0.038749      -0.044285   -0.037089
# totChol         -0.070413  0.262554  -0.023613      -0.046488   -0.026479
# sysBP           -0.035879  0.394053  -0.129496      -0.130281   -0.088797
# diaBP            0.058199  0.205586  -0.061919      -0.107933   -0.056715
# BMI              0.081871  0.136096  -0.137747      -0.167857   -0.093293
# heartRate       -0.116932 -0.012843  -0.054182       0.062686    0.075564
# glucose          0.005979  0.122356  -0.035843      -0.056726   -0.058886
# TenYearCHD       0.088374  0.225408  -0.054248       0.019448    0.057755
#
#                    BPMeds  prevalentStroke  prevalentHyp  diabetes   totChol  \
# male            -0.052504        -0.004550      0.005853  0.015693 -0.070413
# age              0.123052         0.057679      0.306799  0.101314  0.262554
# education       -0.010898        -0.035142     -0.081726 -0.038749 -0.023613
# currentSmoker   -0.048927        -0.032980     -0.103710 -0.044285 -0.046488
# cigsPerDay      -0.046155        -0.032711     -0.066645 -0.037089 -0.026479
# BPMeds           1.000000         0.117370      0.261067  0.052060  0.080623
# prevalentStroke  0.117370         1.000000      0.074791  0.006955  0.000105
# prevalentHyp     0.261067         0.074791      1.000000  0.077752  0.163632
# diabetes         0.052060         0.006955      0.077752  1.000000  0.040348
# totChol          0.080623         0.000105      0.163632  0.040348  1.000000
# sysBP            0.254194         0.057000      0.696656  0.111265  0.208734
# diaBP            0.194122         0.045153      0.615840  0.050260  0.164698
# BMI              0.100702         0.025909      0.301344  0.087068  0.115992
# heartRate        0.015230        -0.017674      0.146815  0.048986  0.091127
# glucose          0.051197         0.018440      0.086656  0.617630  0.046538
# TenYearCHD       0.087519         0.061823      0.177458  0.097344  0.082369
#
#                     sysBP     diaBP       BMI  heartRate   glucose  TenYearCHD
# male            -0.035879  0.058199  0.081871  -0.116932  0.005979    0.088374
# age              0.394053  0.205586  0.136096  -0.012843  0.122356    0.225408
# education       -0.129496 -0.061919 -0.137747  -0.054182 -0.035843   -0.054248
# currentSmoker   -0.130281 -0.107933 -0.167857   0.062686 -0.056726    0.019448
# cigsPerDay      -0.088797 -0.056715 -0.093293   0.075564 -0.058886    0.057755
# BPMeds           0.254194  0.194122  0.100702   0.015230  0.051197    0.087519
# prevalentStroke  0.057000  0.045153  0.025909  -0.017674  0.018440    0.061823
# prevalentHyp     0.696656  0.615840  0.301344   0.146815  0.086656    0.177458
# diabetes         0.111265  0.050260  0.087068   0.048986  0.617630    0.097344
# totChol          0.208734  0.164698  0.115992   0.091127  0.046538    0.082369
# sysBP            1.000000  0.783952  0.326906   0.182155  0.140573    0.216374
# diaBP            0.783952  1.000000  0.377360   0.181021  0.061075    0.145112
# BMI              0.326906  0.377360  1.000000   0.067451  0.087389    0.075300
# heartRate        0.182155  0.181021  0.067451   1.000000  0.094546    0.022907
# glucose          0.140573  0.061075  0.087389   0.094546  1.000000    0.125590
# TenYearCHD       0.216374  0.145112  0.075300   0.022907  0.125590    1.000000

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# min       0.000000         0.000000      0.000000     0.000000   107.000000
# 25%       0.000000         0.000000      0.000000     0.000000   206.000000
# 50%       0.000000         0.000000      0.000000     0.000000   234.000000
# 75%       0.000000         0.000000      1.000000     0.000000   263.000000
# max       1.000000         1.000000      1.000000     1.000000   696.000000
#
#              sysBP        diaBP          BMI    heartRate      glucose  \
# count  4240.000000  4240.000000  4221.000000  4239.000000  3852.000000
# mean    132.354599    82.897759    25.800801    75.878981    81.963655
# std      22.033300    11.910394     4.079840    12.025348    23.954335
# min      83.500000    48.000000    15.540000    44.000000    40.000000
# 25%     117.000000    75.000000    23.070000    68.000000    71.000000
# 50%     128.000000    82.000000    25.400000    75.000000    78.000000
# 75%     144.000000    90.000000    28.040000    83.000000    87.000000
# max     295.000000   142.500000    56.800000   143.000000   394.000000
#
#         TenYearCHD
# count  4240.000000
# mean      0.151887
# std       0.358953
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df['age'].unique()
# Out:
# array([39, 46, 48, 61, 43, 63, 45, 52, 50, 41, 38, 42, 44, 47, 60, 35, 36,
#        59, 54, 37, 56, 53, 49, 65, 51, 62, 40, 67, 57, 66, 64, 55, 58, 34,
#        68, 33, 70, 32, 69])

# %%
df['education'].unique()
# Out:
# array([ 4.,  2.,  1.,  3., nan])

# %%
df['currentSmoker'].unique()
# Out:
# array([0, 1])

# %%
df['cigsPerDay'].unique()
# Out:
# array([ 0., 20., 30., 23., 15.,  9., 10.,  5., 35., 43.,  1., 40.,  3.,
#         2., nan, 12.,  4., 18., 25., 60., 14., 45.,  8., 50., 13., 11.,
#         7.,  6., 38., 29., 17., 16., 19., 70.])

# %%
df['BPMeds'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
df['prevalentStroke'].unique()
# Out:
# array([0, 1])

# %%
df['prevalentHyp'].unique()
# Out:
# array([0, 1])

# %%
df['diabetes'].unique()
# Out:
# array([0, 1])

# %%
df['totChol'].unique()
# Out:
# array([195., 250., 245., 225., 285., 228., 205., 313., 260., 254., 247.,
#        294., 332., 226., 221., 232., 291., 190., 185., 234., 215., 270.,
#        272., 295., 209., 175., 214., 257., 178., 233., 180., 243., 237.,
#         nan, 311., 208., 252., 261., 179., 194., 267., 216., 240., 266.,
#        255., 220., 235., 212., 223., 300., 302., 248., 200., 189., 258.,
#        202., 213., 183., 274., 170., 210., 197., 326., 188., 256., 244.,
#        193., 239., 296., 269., 275., 268., 265., 173., 273., 290., 278.,
#        264., 282., 241., 288., 222., 303., 246., 150., 187., 286., 154.,
#        279., 293., 259., 219., 230., 320., 312., 165., 159., 174., 242.,
#        301., 167., 308., 325., 229., 236., 224., 253., 464., 171., 186.,
#        227., 249., 176., 163., 191., 263., 196., 310., 164., 135., 238.,
#        207., 342., 287., 182., 352., 284., 217., 203., 262., 129., 155.,
#        323., 206., 283., 319., 304., 340., 328., 280., 368., 218., 276.,
#        339., 231., 198., 177., 201., 277., 184., 199., 168., 292., 305.,
#        306., 152., 161., 181., 251., 271., 370., 439., 145., 330., 157.,
#        398., 162., 314., 166., 160., 281., 289., 355., 307., 156., 329.,
#         69. ,  93. ,  66. ,  75. ,  79. ,  87. ,  99. ,  60. ,  67.5,
#        106. ,  86.5, 104. ,  86. ,  61.5,  71.5,  76.5,  77. ,  88.5,
#        105. ,  96. ,  97. , 100. ,  81.5, 106.5,  80.5, 124.5,  61. ,
#         83. ,  67. ,  74.5,  66.5,  65. ,  72. ,  99.5, 122.5,  57. ,
#         57.5, 111. ,  78.5, 104.5,  89.5, 112. ,  55. , 123. , 120. ,
#         75.5, 118. ,  97.5,  59. , 133. ,  69.5,  95.5,  96.5, 135. ,
#         64.5,  68.5,  98.5,  62. , 117. ,  59.5, 103. , 108.5,  73.5,
#         87.5, 108. ,  93.5,  90.5, 114.5,  62.5,  94.5, 140. , 124. ,
#         79.5, 109. ,  91.5, 115. , 102.5,  65.5, 105.5, 103.5,  63.5,
#        107.5, 142.5, 109.5,  58. , 117.5, 116.5, 100.5, 116. , 119. ,
#         54. , 132. ,  50. , 101.5, 136. ,  51. , 128. , 125. , 112.5,
#        130. , 110.5, 113. ,  53. , 129. ,  52. ,  48. ,  56. ,  60.5,
#        115.5, 127.5])

# %%
df['BMI'].unique()
# Out:
# array([26.97, 28.73, 25.34, ..., 26.7 , 43.67, 20.91], shape=(1365,))

# %%
df['heartRate'].unique()
# Out:
# array([ 80.,  95.,  75.,  65.,  85.,  77.,  60.,  79.,  76.,  93.,  72.,
#         98.,  64.,  70.,  71.,  62.,  73.,  90.,  96.,  68.,  63.,  88.,
#         78.,  83., 100.,  67.,  84.,  57.,  50.,  74.,  86.,  55.,  92.,
#         66.,  87., 110.,  81.,  56.,  89.,  82.,  48., 105.,  61.,  54.,
#         69.,  52.,  94., 140., 130.,  58., 108., 104.,  91.,  53.,  nan,
#        106.,  59.,  51., 102., 107., 112., 125., 103.,  44.,  47.,  45.,
#         97., 122., 120.,  99., 115., 143., 101.,  46.])

# %%
df['glucose'].unique()
# Out:
# array([ 77.,  76.,  70., 103.,  85.,  99.,  78.,  79.,  88.,  61.,  64.,
#         84.,  nan,  72.,  89.,  65., 113.,  75.,  83.,  66.,  74.,  63.,
#         87., 225.,  90.,  80., 100., 215.,  98.,  62.,  95.,  94.,  55.,
#         82.,  93.,  73.,  45., 202.,  68.,  97., 104.,  96., 126., 120.,
#        105.,  71.,  56.,  60., 117., 102.,  58.,  92., 109.,  86., 107.,
#         54.,  67.,  69.,  57.,  91., 132., 150.,  59.,  81., 115., 140.,
#        112., 118., 143., 114., 160., 110., 123., 108., 145., 122., 137.,
#        106., 127., 205., 130., 101.,  47.,  53., 216., 163., 144., 116.,
#        121., 172., 124., 111.,  40., 186., 223., 325.,  44., 156., 268.,
#         50., 274., 292., 255., 136., 206., 131., 148., 297.,  43., 173.,
#         48., 386., 155., 147., 170.,  52., 320., 254., 394., 270., 244.,
#        183., 142., 119., 135., 167., 207., 129., 177., 250., 294., 166.,
#        125., 332., 368., 348., 248., 370., 193., 191., 256., 235., 210.,
#        260.])

# %%
df['TenYearCHD'].unique()
# Out:
# array([0, 1])

# %%
df.isnull().sum().sum()
# Out:
# np.int64(645)

# %%
df = df.fillna(df.median(numeric_only=True))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4240 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4240 non-null   float64
#  5   BPMeds           4240 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4240 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4240 non-null   float64
#  13  heartRate        4240 non-null   float64
#  14  glucose          4240 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 530.1 KB

# %%
# Features (X) and target (y)
X = df.drop("TenYearCHD", axis=1)   # target column remove
y = df["TenYearCHD"]                 # target column

# 80-20 split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,      # 20% testing
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (3392, 15)
# (848, 15)

# %%
train_df = X_train.copy()
train_df["TenYearCHD"] = y_train
val_df = X_test.copy()
val_df["TenYearCHD"] = y_test

# %%
def dataframe_to_dataset(df):
    df = df.copy()
    labels = df.pop('TenYearCHD')
    ds = tf.data.Dataset.from_tensor_slices(
        (dict(df), labels)
    )
    ds = ds.shuffle(buffer_size=len(df))
    return ds

# %%
train_ds = dataframe_to_dataset(train_df)
val_ds   = dataframe_to_dataset(val_df)
train_ds = train_ds.batch(32)
val_ds   = val_ds.batch(32)

# %%
from keras.utils import FeatureSpace

feature_space = FeatureSpace(
    features={
        # Categorical
        'male': 'integer_categorical',
        'currentSmoker': 'integer_categorical',
        'BPMeds': 'integer_categorical',
        'prevalentStroke': 'integer_categorical',
        'prevalentHyp': 'integer_categorical',
        'diabetes': 'integer_categorical',
        'education': 'integer_categorical',

        # Numerical
        'age': 'float_normalized',
        'cigsPerDay': 'float_normalized',
        'totChol': 'float_normalized',
        'sysBP': 'float_normalized',
        'diaBP': 'float_normalized',
        'BMI': 'float_normalized',
        'heartRate': 'float_normalized',
        'glucose': 'float_normalized',
    }
)


train_ds_with_no_labels = train_ds.map(lambda x, y: x)

feature_space.adapt(train_ds_with_no_labels)


for x, _ in train_ds.take(1):
    preprocessed_x = feature_space(x)
    print(preprocessed_x)

preprocessed_train_ds = train_ds.map(
    lambda x, y: (feature_space(x), y),
    num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)

preprocessed_val_ds = val_ds.map(
    lambda x, y: (feature_space(x), y),
    num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
# Out:
# tf.Tensor(
# [[-0.04034866  0.          1.          0.          0.9845019  -0.7637733
#    0.          0.          1.         -2.5791295   0.          1.
#    0.          0.          1.          0.          0.          0.
#   -0.82006836 -0.09166135  0.          1.          0.          0.
#    1.          0.          0.          1.          0.         -0.29036278
#    0.06525155]
#  [-0.49720317  0.          1.          0.         -1.0036678  -0.7637733
#    0.          0.          1.         -1.0812652   0.          1.
#    0.          0.          0.          1.          0.          0.
#    0.36120114 -0.9283423   0.          1.          0.          0.
#    1.          0.          0.          1.          0.         -0.8741237
#   -0.9227134 ]
#  [ 1.1285189   0.          1.          0.          1.5692576  -0.7637733
#    0.          0.          1.          1.1655313   0.          1.
#    0.          0.          0.          1.          0.          0.
#    0.62370545 -1.3466828   0.          1.          0.          0.
#    0.          1.          0.          1.          0.          2.4263709
#    1.2829758 ]
#  [-1.3866118   0.          1.          0.          0.5166973   1.7502687
#    0.          1.          0.          0.25016972  0.          1.
#    0.          0.          1.          0.          0.          0.
#   -0


# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(
    preprocessed_train_ds,
    validation_data=preprocessed_val_ds,
    epochs=10
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8464 - loss: 0.4315 - val_accuracy: 0.8550 - val_loss: 0.3903
# Epoch 2/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8496 - loss: 0.3917 - val_accuracy: 0.8550 - val_loss: 0.3862
# Epoch 3/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8508 - loss: 0.3860 - val_accuracy: 0.8550 - val_loss: 0.3859
# Epoch 4/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8523 - loss: 0.3820 - val_accuracy: 0.8561 - val_loss: 0.3831
# Epoch 5/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8544 - loss: 0.3798 - val_accuracy: 0.8573 - val_loss: 0.3835
# Epoch 6/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8555 - loss: 0.3776 - val_accuracy: 0.8573 - val_loss: 0.3828
# Epoch 7/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8547 - loss: 0.3760 - val_accuracy: 0.8573 - val_loss: 0.3837
# Epoch 8/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8547 - loss: 0.3750 - val_accuracy: 0.8573 - val_loss: 0.3824
# Epoch 9/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8561 - loss: 0.3728 - val_accuracy: 0.8573 - val_loss: 0.3842
# Epoch 10/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8547 - loss: 0.3715 - val_accuracy: 0.8585 - val_loss: 0.3836

# %%
training_model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

training_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

training_model.summary()

history = training_model.fit(
    preprocessed_train_ds,
    validation_data=preprocessed_val_ds,
    epochs=10
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8461 - loss: 0.4407 - val_accuracy: 0.8550 - val_loss: 0.3902
# Epoch 2/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8461 - loss: 0.3912 - val_accuracy: 0.8550 - val_loss: 0.3803
# Epoch 3/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8464 - loss: 0.3834 - val_accuracy: 0.8573 - val_loss: 0.3781
# Epoch 4/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8496 - loss: 0.3800 - val_accuracy: 0.8573 - val_loss: 0.3777
# Epoch 5/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8502 - loss: 0.3780 - val_accuracy: 0.8597 - val_loss: 0.3774
# Epoch 6/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8502 - loss: 0.3764 - val_accuracy: 0.8585 - val_loss: 0.3776
# Epoch 7/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8520 - loss: 0.3752 - val_accuracy: 0.8573 - val_loss: 0.3773
# Epoch 8/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8544 - loss: 0.3738 - val_accuracy: 0.8573 - val_loss: 0.3785
# Epoch 9/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8529 - loss: 0.3726 - val_accuracy: 0.8585 - val_loss: 0.3797
# Epoch 10/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8538 - loss: 0.3713 - val_accuracy: 0.8573 - val_loss: 0.3794

# %%
for batch_x, _ in train_ds.take(1):
    example_batch = batch_x
    break

inputs = {
    key: tf.keras.Input(shape=(1,), name=key, dtype=value.dtype)
    for key, value in example_batch.items()
}

def preprocess_fn(inputs):
    return feature_space(inputs)
x = tf.keras.layers.Lambda(preprocess_fn)(inputs)
outputs = training_model(x)
inference_model = tf.keras.Model(inputs=inputs, outputs=outputs)
inference_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ BMI (InputLayer)    │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BPMeds (InputLayer) │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age (InputLayer)    │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cigsPerDay          │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ currentSmoker       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ diaBP (InputLayer)  │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ diabetes            │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ education           │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ glucose             │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ heartRate           │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ male (InputLayer)   │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ prevalentHyp        │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ prevalentStroke     │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sysBP (InputLayer)  │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ totChol             │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 31)        │          0 │ BMI[0][0],        │
# │                     │                   │            │ BPMeds[0][0],     │
# │                     │                   │            │ age[0][0],        │
# │                     │                   │            │ cigsPerDay[0][0], │
# │                     │                   │            │ currentSmoker[0]… │
# │                     │                   │            │ diaBP[0][0],      │
# │                     │                   │            │ diabetes[0][0],   │
# │                     │                   │            │ education[0][0],  │
# │                     │                   │            │ glucose[0][0],    │
# │                     │                   │            │ heartRate[0][0],  │
# │                     │                   │            │ male[0][0],       │
# │                     │                   │            │ prevalentHyp[0][… │
# │                     │                   │            │ prevalentStroke[… │
# │                     │                   │            │ sysBP[0][0],      │
# │                     │                   │            │ totChol[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, 1)         │      1,569 │ lambda[0][0]      │
# │ (Sequential)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,569 (6.13 KB)
#  Trainable params: 1,569 (6.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Model training
training_model.fit(
    preprocessed_train_ds,
    validation_data=preprocessed_val_ds,
    epochs=10,
    verbose=2

)
# Out:
# Epoch 1/10
# 106/106 - 2s - 14ms/step - accuracy: 0.8550 - loss: 0.3675 - val_accuracy: 0.8585 - val_loss: 0.3801
# Epoch 2/10
# 106/106 - 1s - 11ms/step - accuracy: 0.8552 - loss: 0.3654 - val_accuracy: 0.8502 - val_loss: 0.3834
# Epoch 3/10
# 106/106 - 1s - 10ms/step - accuracy: 0.8564 - loss: 0.3654 - val_accuracy: 0.8502 - val_loss: 0.3834
# Epoch 4/10
# 106/106 - 1s - 10ms/step - accuracy: 0.8576 - loss: 0.3644 - val_accuracy: 0.8526 - val_loss: 0.3822
# Epoch 5/10
# 106/106 - 1s - 9ms/step - accuracy: 0.8588 - loss: 0.3614 - val_accuracy: 0.8514 - val_loss: 0.3831
# Epoch 6/10
# 106/106 - 1s - 10ms/step - accuracy: 0.8597 - loss: 0.3604 - val_accuracy: 0.8502 - val_loss: 0.3832
# Epoch 7/10
# 106/106 - 1s - 9ms/step - accuracy: 0.8620 - loss: 0.3588 - val_accuracy: 0.8491 - val_loss: 0.3860
# Epoch 8/10
# 106/106 - 1s - 9ms/step - accuracy: 0.8606 - loss: 0.3587 - val_accuracy: 0.8491 - val_loss: 0.3884
# Epoch 9/10
# 106/106 - 1s - 9ms/step - accuracy: 0.8606 - loss: 0.3570 - val_accuracy: 0.8514 - val_loss: 0.3839
# Epoch 10/10
# 106/106 - 1s - 10ms/step - accuracy: 0.8617 - loss: 0.3558 - val_accuracy: 0.8538 - val_loss: 0.3849

# %%
sample = {
    'male': 1,
    'age': 55.0,
    'education': 2,
    'currentSmoker': 0,
    'cigsPerDay': 0.0,
    'BPMeds': 0,
    'prevalentStroke': 0,
    'prevalentHyp': 1,
    'diabetes': 0,
    'totChol': 233.0,
    'sysBP': 145.0,
    'diaBP': 90.0,
    'BMI': 28.0,
    'heartRate': 75.0,
    'glucose': 85.0
}

# %%
input_dict = {
    name: tf.convert_to_tensor([value])
    for name, value in sample.items()
}

# %%
prediction = inference_model.predict(input_dict)

print(
    f"This patient has a {100 * prediction[0][0]:.2f}% probability "
    "of having heart disease."
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# This patient has a 17.65% probability of having heart disease.

# %%
inference_model.save("heart_disease_model.keras")
