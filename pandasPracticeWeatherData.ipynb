# %%
import pandas as pd
df = pd.read_csv('C:/Users/BEST LAPTOP/Desktop/AI/weather.csv')
df
# Out:
#     MIN temp (deg Celcius)                       Location       Time  \
# 0                       22  Bharsul, India 10-day Weather  23:04 IST
# 1                       22  Bharsul, India 10-day Weather  23:04 IST
# 2                       22  Bharsul, India 10-day Weather  23:04 IST
# 3                       21  Bharsul, India 10-day Weather  23:04 IST
# 4                       21  Bharsul, India 10-day Weather  23:04 IST
# 5                       21  Bharsul, India 10-day Weather  23:04 IST
# 6                       21  Bharsul, India 10-day Weather  23:04 IST
# 7                       20  Bharsul, India 10-day Weather  23:04 IST
# 8                       20  Bharsul, India 10-day Weather  23:04 IST
# 9                       19  Bharsul, India 10-day Weather  23:04 IST
# 10                      19  Bharsul, India 10-day Weather  23:04 IST
# 11                      19  Bharsul, India 10-day Weather  23:04 IST
# 12                      19  Bharsul, India 10-day Weather  23:04 IST
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MIN temp (deg Celcius)  31 non-null     object
#  1   Location                31 non-null     object
#  2   Time                    31 non-null     object
#  3   Wind                    31 non-null     object
#  4   MAX temp (deg Celcius)  31 non-null     object
#  5   Description             31 non-null     object
#  6   Precipitation (in %)    31 non-null     object
#  7   Date                    31 non-null     object
#  8   Other Details           31 non-null     object
#  9   Humidity (in %)         31 non-null     object
#  10  Day                     31 non-null     object
# dtypes: object(11)
# memory usage: 2.8+ KB

# %%
df.describe()
# Out:
#        MIN temp (deg Celcius)                       Location       Time  \
# count                      31                             31         31
# unique                      5                              2          2
# top                        19  Bharsul, India 10-day Weather  23:04 IST
# freq                       12                             30         30
#
#               Wind MAX temp (deg Celcius) Description Precipitation (in %)  \
# count           31                     31          31                   31
# unique          16                      6           4                    2
# top     NE 2 km/h                      33       Sunny                    0
# freq             2                     10          20                   30
#
#           Date                                      Other Details  \
# count       31                                                 31
# unique      16                                                 16
# ...

# %%
df.head()
# Out:
#   MIN temp (deg Celcius)                       Location       Time  \
# 0                     22  Bharsul, India 10-day Weather  23:04 IST
# 1                     22  Bharsul, India 10-day Weather  23:04 IST
# 2                     22  Bharsul, India 10-day Weather  23:04 IST
# 3                     21  Bharsul, India 10-day Weather  23:04 IST
# 4                     21  Bharsul, India 10-day Weather  23:04 IST
#
#           Wind MAX temp (deg Celcius)   Description Precipitation (in %)  \
# 0   NE 2 km/h                      --         Clear                    0
# 1  NNW 7 km/h                      36  Mostly Sunny                    0
# 2  SSW 5 km/h                      35         Sunny                    0
# 3  WSW 9 km/h                      36         Sunny                    0
# 4    N 9 km/h                      35         Sunny                    0
#
#      Date                                      Other Details Humidity (in %)  \
# ...

# %%
df.tail()
# Out:
#    MIN temp (deg Celcius)                       Location       Time  \
# 26                     19  Bharsul, India 10-day Weather  23:04 IST
# 27                     19  Bharsul, India 10-day Weather  23:04 IST
# 28                     19  Bharsul, India 10-day Weather  23:04 IST
# 29                     19  Bharsul, India 10-day Weather  23:04 IST
# 30                     19  Bharsul, India 10-day Weather  23:04 IST
#
#            Wind MAX temp (deg Celcius) Description Precipitation (in %)  \
# 26   NE 7 km/h                      33       Sunny                    0
# 27  ENE 6 km/h                      33       Sunny                    0
# 28    E 6 km/h                      33       Sunny                    0
# 29  ESE 5 km/h                      33       Sunny                    0
# 30  NNW 5 km/h                      33       Sunny                    0
#
#       Date                                      Other Details Humidity (in %)  \
# ...

# %%
df[df.duplicated()] #Shows only duplicate rows.
# Out:
#    MIN temp (deg Celcius)                       Location       Time  \
# 16                     22  Bharsul, India 10-day Weather  23:04 IST
# 17                     22  Bharsul, India 10-day Weather  23:04 IST
# 18                     22  Bharsul, India 10-day Weather  23:04 IST
# 19                     21  Bharsul, India 10-day Weather  23:04 IST
# 20                     21  Bharsul, India 10-day Weather  23:04 IST
# 21                     21  Bharsul, India 10-day Weather  23:04 IST
# 22                     21  Bharsul, India 10-day Weather  23:04 IST
# 23                     20  Bharsul, India 10-day Weather  23:04 IST
# 24                     20  Bharsul, India 10-day Weather  23:04 IST
# 25                     19  Bharsul, India 10-day Weather  23:04 IST
# 26                     19  Bharsul, India 10-day Weather  23:04 IST
# 27                     19  Bharsul, India 10-day Weather  23:04 IST
# 28                     19  Bharsul, India 10-day Weather  23:04 IST
# ...

# %%
df[df['Location'].duplicated()] #Check duplicates in a specific column
# Out:
#    MIN temp (deg Celcius)                       Location       Time  \
# 1                      22  Bharsul, India 10-day Weather  23:04 IST
# 2                      22  Bharsul, India 10-day Weather  23:04 IST
# 3                      21  Bharsul, India 10-day Weather  23:04 IST
# 4                      21  Bharsul, India 10-day Weather  23:04 IST
# 5                      21  Bharsul, India 10-day Weather  23:04 IST
# 6                      21  Bharsul, India 10-day Weather  23:04 IST
# 7                      20  Bharsul, India 10-day Weather  23:04 IST
# 8                      20  Bharsul, India 10-day Weather  23:04 IST
# 9                      19  Bharsul, India 10-day Weather  23:04 IST
# 10                     19  Bharsul, India 10-day Weather  23:04 IST
# 11                     19  Bharsul, India 10-day Weather  23:04 IST
# 12                     19  Bharsul, India 10-day Weather  23:04 IST
# 13                     19  Bharsul, India 10-day Weather  23:04 IST
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# dtype: bool

# %%
df.drop_duplicates() # drop duplicates
# Out:
#     MIN temp (deg Celcius)                       Location       Time  \
# 0                       22  Bharsul, India 10-day Weather  23:04 IST
# 1                       22  Bharsul, India 10-day Weather  23:04 IST
# 2                       22  Bharsul, India 10-day Weather  23:04 IST
# 3                       21  Bharsul, India 10-day Weather  23:04 IST
# 4                       21  Bharsul, India 10-day Weather  23:04 IST
# 5                       21  Bharsul, India 10-day Weather  23:04 IST
# 6                       21  Bharsul, India 10-day Weather  23:04 IST
# 7                       20  Bharsul, India 10-day Weather  23:04 IST
# 8                       20  Bharsul, India 10-day Weather  23:04 IST
# 9                       19  Bharsul, India 10-day Weather  23:04 IST
# 10                      19  Bharsul, India 10-day Weather  23:04 IST
# 11                      19  Bharsul, India 10-day Weather  23:04 IST
# 12                      19  Bharsul, India 10-day Weather  23:04 IST
# ...

# %%
df.drop_duplicates(subset=['Location']) #remove duplictaed from specific col
# Out:
#     MIN temp (deg Celcius)                       Location       Time  \
# 0                       22  Bharsul, India 10-day Weather  23:04 IST
# 15  MIN temp (deg Celcius)                       Location       Time
#
#           Wind  MAX temp (deg Celcius)  Description  Precipitation (in %)  \
# 0   NE 2 km/h                       --        Clear                     0
# 15        Wind  MAX temp (deg Celcius)  Description  Precipitation (in %)
#
#       Date                                      Other Details  \
# 0   18 OCT  Generally clear. Low 22ºC. Winds NE and variable.
# 15    Date                                      Other Details
#
#     Humidity (in %)      Day
# 0                48  Tonight
# 15  Humidity (in %)      Day

# %%
df.shape
# Out:
# (31, 11)

# %%
df.columns
# Out:
# Index(['MIN temp (deg Celcius)', 'Location', 'Time', 'Wind',
#        'MAX temp (deg Celcius)', 'Description', 'Precipitation (in %)', 'Date',
#        'Other Details', 'Humidity (in %)', 'Day'],
#       dtype='object')

# %%
df.dtypes
# Out:
# MIN temp (deg Celcius)    object
# Location                  object
# Time                      object
# Wind                      object
# MAX temp (deg Celcius)    object
# Description               object
# Precipitation (in %)      object
# Date                      object
# Other Details             object
# Humidity (in %)           object
# Day                       object
# dtype: object

# %%
df.sort_values(by='Humidity (in %)') #sort on the assending
# Out:
#     MIN temp (deg Celcius)                       Location       Time  \
# 27                      19  Bharsul, India 10-day Weather  23:04 IST
# 11                      19  Bharsul, India 10-day Weather  23:04 IST
# 23                      20  Bharsul, India 10-day Weather  23:04 IST
# 28                      19  Bharsul, India 10-day Weather  23:04 IST
# 29                      19  Bharsul, India 10-day Weather  23:04 IST
# 12                      19  Bharsul, India 10-day Weather  23:04 IST
# 7                       20  Bharsul, India 10-day Weather  23:04 IST
# 13                      19  Bharsul, India 10-day Weather  23:04 IST
# 30                      19  Bharsul, India 10-day Weather  23:04 IST
# 10                      19  Bharsul, India 10-day Weather  23:04 IST
# 22                      21  Bharsul, India 10-day Weather  23:04 IST
# 26                      19  Bharsul, India 10-day Weather  23:04 IST
# 14                      19  Bharsul, India 10-day Weather  23:04 IST
# ...

# %%
df.sort_values(by='Humidity (in %)', ascending=False) #decending order
# Out:
#     MIN temp (deg Celcius)                       Location       Time  \
# 15  MIN temp (deg Celcius)                       Location       Time
# 16                      22  Bharsul, India 10-day Weather  23:04 IST
# 0                       22  Bharsul, India 10-day Weather  23:04 IST
# 3                       21  Bharsul, India 10-day Weather  23:04 IST
# 19                      21  Bharsul, India 10-day Weather  23:04 IST
# 20                      21  Bharsul, India 10-day Weather  23:04 IST
# 4                       21  Bharsul, India 10-day Weather  23:04 IST
# 25                      19  Bharsul, India 10-day Weather  23:04 IST
# 9                       19  Bharsul, India 10-day Weather  23:04 IST
# 1                       22  Bharsul, India 10-day Weather  23:04 IST
# 24                      20  Bharsul, India 10-day Weather  23:04 IST
# 21                      21  Bharsul, India 10-day Weather  23:04 IST
# 18                      22  Bharsul, India 10-day Weather  23:04 IST
# ...

# %%
df.isnull() #check nullvalues
# Out:
#     MIN temp (deg Celcius)  Location   Time   Wind  MAX temp (deg Celcius)  \
# 0                    False     False  False  False                   False
# 1                    False     False  False  False                   False
# 2                    False     False  False  False                   False
# 3                    False     False  False  False                   False
# 4                    False     False  False  False                   False
# 5                    False     False  False  False                   False
# 6                    False     False  False  False                   False
# 7                    False     False  False  False                   False
# 8                    False     False  False  False                   False
# 9                    False     False  False  False                   False
# 10                   False     False  False  False                   False
# ...

# %%
df.isnull().sum() #Count null values
# Out:
# MIN temp (deg Celcius)    0
# Location                  0
# Time                      0
# Wind                      0
# MAX temp (deg Celcius)    0
# Description               0
# Precipitation (in %)      0
# Date                      0
# Other Details             0
# Humidity (in %)           0
# Day                       0
# dtype: int64

# %%
df.dropna() #drop null values
# Out:
#     MIN temp (deg Celcius)                       Location       Time  \
# 0                       22  Bharsul, India 10-day Weather  23:04 IST
# 1                       22  Bharsul, India 10-day Weather  23:04 IST
# 2                       22  Bharsul, India 10-day Weather  23:04 IST
# 3                       21  Bharsul, India 10-day Weather  23:04 IST
# 4                       21  Bharsul, India 10-day Weather  23:04 IST
# 5                       21  Bharsul, India 10-day Weather  23:04 IST
# 6                       21  Bharsul, India 10-day Weather  23:04 IST
# 7                       20  Bharsul, India 10-day Weather  23:04 IST
# 8                       20  Bharsul, India 10-day Weather  23:04 IST
# 9                       19  Bharsul, India 10-day Weather  23:04 IST
# 10                      19  Bharsul, India 10-day Weather  23:04 IST
# 11                      19  Bharsul, India 10-day Weather  23:04 IST
# 12                      19  Bharsul, India 10-day Weather  23:04 IST
# ...

# %%
df.fillna(0) #fill null values with zero
# Out:
#     MIN temp (deg Celcius)                       Location       Time  \
# 0                       22  Bharsul, India 10-day Weather  23:04 IST
# 1                       22  Bharsul, India 10-day Weather  23:04 IST
# 2                       22  Bharsul, India 10-day Weather  23:04 IST
# 3                       21  Bharsul, India 10-day Weather  23:04 IST
# 4                       21  Bharsul, India 10-day Weather  23:04 IST
# 5                       21  Bharsul, India 10-day Weather  23:04 IST
# 6                       21  Bharsul, India 10-day Weather  23:04 IST
# 7                       20  Bharsul, India 10-day Weather  23:04 IST
# 8                       20  Bharsul, India 10-day Weather  23:04 IST
# 9                       19  Bharsul, India 10-day Weather  23:04 IST
# 10                      19  Bharsul, India 10-day Weather  23:04 IST
# 11                      19  Bharsul, India 10-day Weather  23:04 IST
# 12                      19  Bharsul, India 10-day Weather  23:04 IST
# ...

# %%
df['Wind'] # select single col
# Out:
# 0      NE 2 km/h
# 1     NNW 7 km/h
# 2     SSW 5 km/h
# 3     WSW 9 km/h
# 4       N 9 km/h
# 5       W 8 km/h
# 6     SSE 7 km/h
# 7     SSW 9 km/h
# 8       E 7 km/h
# 9     NE 10 km/h
# 10     NE 7 km/h
# 11    ENE 6 km/h
# 12      E 6 km/h
# 13    ESE 5 km/h
# 14    NNW 5 km/h
# 15           Wind
# 16     NE 2 km/h
# 17    NNW 7 km/h
# 18    SSW 5 km/h
# 19    WSW 9 km/h
# 20      N 9 km/h
# 21      W 8 km/h
# 22    SSE 7 km/h
# 23    SSW 9 km/h
# 24      E 7 km/h
# 25    NE 10 km/h
# 26     NE 7 km/h
# 27    ENE 6 km/h
# 28      E 6 km/h
# 29    ESE 5 km/h
# 30    NNW 5 km/h
# Name: Wind, dtype: object

# %%
df[['Location','Wind']] #select multiple col
# Out:
#                          Location         Wind
# 0   Bharsul, India 10-day Weather   NE 2 km/h
# 1   Bharsul, India 10-day Weather  NNW 7 km/h
# 2   Bharsul, India 10-day Weather  SSW 5 km/h
# 3   Bharsul, India 10-day Weather  WSW 9 km/h
# 4   Bharsul, India 10-day Weather    N 9 km/h
# 5   Bharsul, India 10-day Weather    W 8 km/h
# 6   Bharsul, India 10-day Weather  SSE 7 km/h
# 7   Bharsul, India 10-day Weather  SSW 9 km/h
# 8   Bharsul, India 10-day Weather    E 7 km/h
# 9   Bharsul, India 10-day Weather  NE 10 km/h
# 10  Bharsul, India 10-day Weather   NE 7 km/h
# 11  Bharsul, India 10-day Weather  ENE 6 km/h
# 12  Bharsul, India 10-day Weather    E 6 km/h
# 13  Bharsul, India 10-day Weather  ESE 5 km/h
# 14  Bharsul, India 10-day Weather  NNW 5 km/h
# 15                       Location         Wind
# 16  Bharsul, India 10-day Weather   NE 2 km/h
# 17  Bharsul, India 10-day Weather  NNW 7 km/h
# 18  Bharsul, India 10-day Weather  SSW 5 km/h
# ...

# %%
df[df['Humidity (in %)'] > 10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df[df['Humidity (in %)'] > 10]
#
# File c:\Users\BEST LAPTOP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\BEST LAPTOP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Users\BEST LAPTOP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6138, in Series._cmp_method(self, other, op)
#    6135 lvalues = self._values
# ...

# %%
df.rename(columns={'Humidity (in %)':'Humidity'}, inplace=True) #rename the col

# %%
df
# Out:
#     MIN temp (deg Celcius)                       Location       Time  \
# 0                       22  Bharsul, India 10-day Weather  23:04 IST
# 1                       22  Bharsul, India 10-day Weather  23:04 IST
# 2                       22  Bharsul, India 10-day Weather  23:04 IST
# 3                       21  Bharsul, India 10-day Weather  23:04 IST
# 4                       21  Bharsul, India 10-day Weather  23:04 IST
# 5                       21  Bharsul, India 10-day Weather  23:04 IST
# 6                       21  Bharsul, India 10-day Weather  23:04 IST
# 7                       20  Bharsul, India 10-day Weather  23:04 IST
# 8                       20  Bharsul, India 10-day Weather  23:04 IST
# 9                       19  Bharsul, India 10-day Weather  23:04 IST
# 10                      19  Bharsul, India 10-day Weather  23:04 IST
# 11                      19  Bharsul, India 10-day Weather  23:04 IST
# 12                      19  Bharsul, India 10-day Weather  23:04 IST
# ...

# %%
df[df['MAX temp (deg Celcius)'] > 30]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df[df['MAX temp (deg Celcius)'] > 30]
#
# File c:\Users\BEST LAPTOP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\BEST LAPTOP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Users\BEST LAPTOP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6138, in Series._cmp_method(self, other, op)
# ...

# %%
df[df['Location'] == 'Bharsul, India']
# Out:
# Empty DataFrame
# Columns: [MIN temp (deg Celcius), Location, Time, Wind, MAX temp (deg Celcius), Description, Precipitation (in %), Date, Other Details, Humidity, Day]
# Index: []

# %%
df.groupby('Location')['MAX temp (deg Celcius)'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\BEST LAPTOP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File c:\Users\BEST LAPTOP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...
