# %% [markdown]
# ## ASSIGNMENT 3: Simple Linear Regression from Scratch

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = np.array([35, 40, 50, 55, 65, 70, 75, 85])
m = 0   # slope
b = 0   # intercept
learning_rate = 0.01
epochs = 1000
n = len(X)
for i in range(epochs):

    #Prediction
    y_pred = m * X + b

    cost = (1/n) * np.sum((y - y_pred)**2)

    #Gradients
    m_gradient = (-2/n) * np.sum(X * (y - y_pred))
    b_gradient = (-2/n) * np.sum(y - y_pred)

    #Update parameters
    m = m - learning_rate * m_gradient
    b = b - learning_rate * b_gradient

    #Print cost every 100 epochs
    if i % 100 == 0:
        print(f"Epoch {i}, Cost: {cost:.2f}")
print("Final slope (m):", round(m, 2))
print("Final intercept (b):", round(b, 2))

#Predictions
pred_4_5 = m * 4.5 + b
pred_7_5 = m * 7.5 + b
print("Prediction for 4.5 hours:", round(pred_4_5, 2))
print("Prediction for 7.5 hours:", round(pred_7_5, 2))

#Plot
plt.scatter(X, y, label="Actual Data")
plt.plot(X, m*X + b, label="Regression Line")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Linear Regression using Gradient Descent")
plt.legend()
plt.show()
# Out:
# Epoch 0, Cost: 3790.62
# Epoch 100, Cost: 61.68
# Epoch 200, Cost: 28.72
# Epoch 300, Cost: 13.91
# Epoch 400, Cost: 7.25
# Epoch 500, Cost: 4.26
# Epoch 600, Cost: 2.92
# Epoch 700, Cost: 2.32
# Epoch 800, Cost: 2.04
# Epoch 900, Cost: 1.92
#
# Final slope (m): 7.17
# Final intercept (b): 27.03
#
# Prediction for 4.5 hours: 59.28
# Prediction for 7.5 hours: 80.78
