# %% [markdown]
# ## First Assessment practice

# %% [markdown]
# ## Tuple

# %%
thistuple=("apple","banana","cherry")
print (len(thistuple))
# Out:
# 3

# %%
thistuple=("apple","bannana","strawbeery")
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
my_list=[2,3,5]
t=tuple(my_list)
print(t)
# Out:
# (2, 3, 5)

# %%
fruits= ("apple","banana")
fruits[1]
# Out:
# 'banana'

# %%
fruits =("apple","apple")
fruits[-1]
# Out:
# 'apple'

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
thistuple = ("apple", "banana", "cherry")
if "apple" in thistuple:
  print("Yes, 'apple' is in the fruits tuple")
# Out:
# Yes, 'apple' is in the fruits tuple

# %%
x=("apple","bannanaa")
y=list(x)
print(y)
y[1] = "kiwi"
x = tuple(y)
print (x)
# Out:
# ['apple', 'bannanaa']
# ('apple', 'kiwi')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)
print(thistuple)
# Out:
# ('banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
del thistuple
